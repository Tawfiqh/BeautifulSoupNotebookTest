# %%
from bs4 import BeautifulSoup
import requests

page = requests.get("https://en.wikipedia.org/wiki/List_of_highest-grossing_films")
soup = BeautifulSoup(page.content)

print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of highest-grossing films - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a91edc8b-fe31-46b2-82a2-16cbb24a5e94","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_highest-grossing_films","wgTitle":"List of highest-grossing films","wgCurRevisionId":961013473,"wgRevisionId":961013473,"wgArticleId":59892,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 uses Russian-language script (ru)","CS1 Russian-language sources (ru)","CS1 errors: missing period

# %%
print(soup.title.string)
# Out:
# List of highest-grossing films - Wikipedia

# %%
film_table = soup.find("table", class_="wikitable")

def clean_string(string):
    if string:
        cleaned_string = string.strip().replace('\n', ' ').strip();
        return cleaned_string
    
    return string

all_results = [];

for row in film_table.find_all("tr"):
    columns = row.find_all(["td", "th"])
    if(columns[0].get("scope")):
        continue;
        
    rank = clean_string(columns[0].text)
    title = clean_string(columns[2].text)
    grossing = clean_string(columns[3].text)
    year = clean_string(columns[4].text)
    
    link_anchor = columns[2].find("a")
    if(link_anchor):
        link_detail = clean_string(link_anchor['href'])
    
    result = (rank, title, link_detail, grossing, year)
    all_results.append(result)

print(all_results)
# Out:
# [('1', 'Avengers: Endgame', '/wiki/Avengers:_Endgame', '$2,797,800,564', '2019'), ('2', 'Avatar', '/wiki/Avatar_(2009_film)', '$2,790,439,000', '2009'), ('3', 'Titanic', '/wiki/Titanic_(1997_film)', '$2,194,439,542', '1997'), ('4', 'Star Wars: The Force Awakens', '/wiki/Star_Wars:_The_Force_Awakens', '$2,068,223,624', '2015'), ('5', 'Avengers: Infinity War', '/wiki/Avengers:_Infinity_War', '$2,048,359,754', '2018'), ('6', 'Jurassic World', '/wiki/Jurassic_World', '$1,671,713,208', '2015'), ('7', 'The Lion King', '/wiki/The_Lion_King_(2019_film)', '$1,656,943,394', '2019'), ('8', 'The Avengers', '/wiki/The_Avengers_(2012_film)', '$1,518,812,988', '2012'), ('9', 'Furious 7', '/wiki/Furious_7', '$1,516,045,911', '2015'), ('10', 'Frozen II', '/wiki/Frozen_II', '$1,450,026,933', '2019'), ('11', 'Avengers: Age of Ultron', '/wiki/Avengers:_Age_of_Ultron', '$1,402,805,868', '2015'), ('12', 'Black Panther', '/wiki/Black_Panther_(film)', '$1,346,913,161', '2018'), ('13', 'Harry Potter and the Deathly Hallows – Part 2', '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2', '$1,341,693,157', '2011'), ('14', 'Star Wars: The Last Jedi', '/wiki/Star_Wars:_The_Last_Jedi', '$1,332,539,889', '2017'), ('15', 'Jurassic World: Fallen Kingdom', '/wiki/Jurassic_World:_Fallen_Kingdom', '$1,309,484,461', '2018'), ('16', 'Frozen', '/wiki/Frozen_(2013_film)', 'F$1,290,000,000', '2013'), ('17', 'Beauty and the Beast', '/wiki/Beauty_and_the_Beast_(2017_film)', '$1,263,521,126', '2017'), ('18', 'Incredibles 2', '/wiki/Incredibles_2', '$1,242,805,359', '2018'), ('19', 'The Fate of the Furious', '/wiki/The_Fate_of_the_Furious', 'F8$1,238,764,765', '2017'), ('20', 'Iron Man 3', '/wiki/Iron_Man_3', '$1,214,811,252', '2013'), ('21', 'Minions', '/wiki/Minions_(film)', '$1,159,398,397', '2015'), ('22', 'Captain America: Civil War', '/wiki/Captain_America:_Civil_War', '$1,153,304,495', '2016'), ('23', 'Aquaman', '/wiki/Aquaman_(film)', '$1,148,161,807', '2018'), ('24', 'The Lord of the Rings: The Return of the King', '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King', '$1,142,219,401', '2003'), ('25', 'Spider-Man: Far From Home', '/wiki/Spider-Man:_Far_From_Home', '$1,131,927,996', '2019'), ('26', 'Captain Marvel', '/wiki/Captain_Marvel_(film)', '$1,128,274,794', '2019'), ('27', 'Transformers: Dark of the Moon', '/wiki/Transformers:_Dark_of_the_Moon', '$1,123,794,079', '2011'), ('28', 'Skyfall', '/wiki/Skyfall', '$1,108,561,013', '2012'), ('29', 'Transformers: Age of Extinction', '/wiki/Transformers:_Age_of_Extinction', '$1,104,054,072', '2014'), ('30', 'The Dark Knight Rises', '/wiki/The_Dark_Knight_Rises', '$1,084,939,099', '2012'), ('31', 'Joker', '/wiki/Joker_(2019_film)', '$1,074,251,311', '2019'), ('32', 'Star Wars: The Rise of Skywalker', '/wiki/Star_Wars:_The_Rise_of_Skywalker', '$1,074,144,248', '2019'), ('33', 'Toy Story 4', '/wiki/Toy_Story_4', '$1,073,394,593', '2019'), ('34', 'Toy Story 3', '/wiki/Toy_Story_3', '$1,066,969,703', '2010'), ('35', "Pirates of the Caribbean: Dead Man's Chest", '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest', '$1,066,179,725', '2006'), ('36', 'Rogue One: A Star Wars Story', '/wiki/Rogue_One:_A_Star_Wars_Story', '$1,056,057,273', '2016'), ('37', 'Aladdin', '/wiki/Aladdin_(2019_film)', '$1,050,693,953', '2019'), ('38', 'Pirates of the Caribbean: On Stranger Tides', '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides', '$1,045,713,802', '2011'), ('39', 'Despicable Me 3', '/wiki/Despicable_Me_3', '$1,034,799,409', '2017'), ('40', 'Jurassic Park', '/wiki/Jurassic_Park_(film)', '$1,029,939,903', '1993'), ('41', 'Finding Dory', '/wiki/Finding_Dory', '$1,028,570,889', '2016'), ('42', 'Star Wars: Episode I – The Phantom Menace', '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace', '$1,027,044,677', '1999'), ('43', 'Alice in Wonderland', '/wiki/Alice_in_Wonderland_(2010_film)', '$1,025,467,110', '2010'), ('44', 'Zootopia', '/wiki/Zootopia', '$1,023,784,195', '2016'), ('45', 'The Hobbit: An Unexpected Journey',  ...

# %%
import pandas as pd

headers = ['rank', 'Title', 'link_detail', "Worldwide gross ($USD)", "Year"]

df = pd.DataFrame(all_results, columns=headers)

df.head(50)
# Out:
#    rank                                          Title  \
# 0     1                              Avengers: Endgame
# 1     2                                         Avatar
# 2     3                                        Titanic
# 3     4                   Star Wars: The Force Awakens
# 4     5                         Avengers: Infinity War
# 5     6                                 Jurassic World
# 6     7                                  The Lion King
# 7     8                                   The Avengers
# 8     9                                      Furious 7
# 9    10                                      Frozen II
# 10   11                        Avengers: Age of Ultron
# 11   12                                  Black Panther
# 12   13  Harry Potter and the Deathly Hallows – Part 2
# 13   14                       Star Wars: The Last Jedi
# 14   15                 Jurassic World: Fallen Kingdom
# 15   16                                         Frozen
# 16   17                           Beauty and the Beast
# 17   18                                  Incredibles 2
# 18   19                        The Fate of the Furious
# 19   20                                     Iron Man 3
# 20   21                                        Minions
# 21   22                     Captain America: Civil War
# 22   23                                        Aquaman
# 23   24  The Lord of the Rings: The Return of the King
# 24   25                      Spider-Man: Far From Home
# 25   26                                 Captain Marvel
# 26   27                 Transformers: Dark of the Moon
# 27   28                                        Skyfall
# 28   29                Transformers: Age of Extinction
# 29   30                          The Dark Knight Rises
# 30   31                                          Joker
# 31   32               Star Wars: The Rise of Skywalker
# 32   33                                    Toy Story 4
# 33   34                                    Toy Story 3
# 34   35     Pirates of the Caribbean: Dead Man's Chest
# 35   36                   Rogue One: A Star Wars Story
# 36   37                                        Aladdin
# 37   38    Pirates of the Caribbean: On Stranger Tides
# 38   39                                Despicable Me 3
# 39   40                                  Jurassic Park
# 40   41                                   Finding Dory
# 41   42      Star Wars: Episode I – The Phantom Menace
# 42   43                            Alice in Wonderland
# 43   44                                       Zootopia
# 44   45              The Hobbit: An Unexpected Journey
# 45   46                                The Dark Knight
# 46   47       Harry Potter and the Philosopher's Stone
# 47   48                                Despicable Me 2
# 48   49                                  The Lion King
# 49   50                                The Jungle Book
#
#                                           link_detail Worldwide gross ($USD)  \
# 0                             /wiki/Avengers:_Endgame         $2,797,800,564
# 1                            /wiki/Avatar_(2009_film)         $2,790,439,000
# 2                           /wiki/Titanic_(1997_film)         $2,194,439,542
# 3                  /wiki/Star_Wars:_The_Force_Awakens         $2,068,223,624
# 4                        /wiki/Avengers:_Infinity_War         $2,048,359,754
# 5                                /wiki/Jurassic_World         $1,671,713,208
# 6                     /wiki/The_Lion_King_(2019_film)         $1,656,943,394
# 7                      /wiki/The_Avengers_(2012_film)         $1,518,812,988
# 8                                     /wiki/Furious_7         $1,516,045,911
# 9                                     /wiki/Frozen_II         $1,450,026,933
# 10                      /wiki/Avengers:_Age_of_Ultron         $1,402,805,868
# 11                         /wiki/Black_Panther_(film)         $1,346,913,161
# 12  /wiki/Harry_Potter_and_the_Deathly_Hallows_%E2...         $1,341,693,157
# 13                     /wiki/Star_Wars:_The_Last_Jedi         $1,332,539,889
# 14               /wiki/Jurassic_World:_Fallen_Kingdom         $1,309,484,461
# 15                           /wiki/Frozen_(2013_film)        F$1,290,000,000
# 16             /wiki/Beauty_and_the_Beast_(2017_film)         $1,263,521,126
# 17                                /wiki/Incredibles_2         $1,242,805,359
# 18                      /wiki/The_Fate_of_the_Furious       F8$1,238,764,765
# 19                                   /wiki/Iron_Man_3         $1,214,811,252
# 20                               /wiki/Minions_(film)         $1,159,398,397
# 21                   /wiki/Captain_America:_Civil_War         $1,153,304,495
# 22                               /wiki/Aquaman_(film)         $1,148,161,807
# 23  /wiki/The_Lord_of_the_Rings:_The_Return_of_the...         $1,142,219,401
# 24                    /wiki/Spider-Man:_Far_From_Home         $1,131,927,996
# 25                        /wiki/Captain_Marvel_(film)         $1,128,274,794
# 26               /wiki/Transformers:_Dark_of_the_Moon         $1,123,794,079
# 27                                      /wiki/Skyfall         $1,108,561,013
# 28              /wiki/Transformers:_Age_of_Extinction         $1,104,054,072
# 29                        /wiki/The_Dark_Knight_Rises         $1,084,939,099
# 30                            /wiki/Joker_(2019_film)         $1,074,251,311
# 31             /wiki/Star_Wars:_The_Rise_of_Skywalker         $1,074,144,248
# 32                                  /wiki/Toy_Story_4         $1,073,394,593
# 33                                  /wiki/Toy_Story_3         $1,066,969,703
# 34  /wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_C...         $1,066,179,725
# 35                 /wiki/Rogue_One:_A_Star_Wars_Story         $1,056,057,273
# 36                          /wiki/Aladdin_(2019_film)         $1,050,693,953
# 37  /wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides         $1,045,713,802
# 38                              /wiki/Despicable_Me_3         $1,034,799,409
# 39                         /wiki/Jurassic_Park_(film)         $1,029,939,903
# 40                                 /wiki/Finding_Dory         $1,028,570,889
# 41  /wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phant...         $1,027,044,677
# 42              /wiki/Alice_in_Wonderland_(2010_film)         $1,025,467,110
# 43                                     /wiki/Zootopia         $1,023,784,195
# 44            /wiki/The_Hobbit:_An_Unexpected_Journey         $1,021,103,568
# 45                       /wiki/The_Dark_Knight_(film)         $1,004,934,033
# 46  /wiki/Harry_Potter_and_the_Philosopher%27s_Sto...           $975,051,288
# 47                              /wiki/Despicable_Me_2           $970,761,885
# 48                                /wiki/The_Lion_King           $968,483,777
# 49                  /wiki/The_Jungle_Book_(2016_film)           $966,550,600
#
#     Year
# 0   2019
# 1   2009
# 2   1997
# 3   2015
# 4   2018
# 5   2015
# 6   2019
# 7   2012
# 8   2015
# 9   2019
# 10  2015
# 11  2018
# 12  2011
# 13  2017
# 14  2018
# 15  2013
# 16  2017
# 17  2018
# 18  2017
# 19  2013
# 20  2015
# 21  2016
# 22  2018
# 23  2003
# 24  2019
# 25  2019
# 26  2011
# 27  2012
# 28  2014
# 29  2012
# 30  2019
# 31  2019
# 32  2019
# 33  2010
# 34  2006
# 35  2016
# 36  2019
# 37  2011
# 38  2017
# 39  1993
# 40  2016
# 41  1999
# 42  2010
# 43  2016
# 44  2012
# 45  2008
# 46  2001
# 47  2013
# 48  1994
# 49  2016

# %%
def from_details_get_film_description(soup):

    main_content = soup.find(class_="mw-parser-output")
    description = ""
    for child in main_content.children:
        if(child.name == "h2"):
            break;
        if(child.name == "p"):
            description += "\n" + child.text

    description = description.strip()
#     print(description)
    return description


def from_details_get_film_director(soup):

    main_content = soup.find("table",  class_="infobox")
    for table_row in main_content.find_all("tr"):
        header = table_row.find('th')
        if(header and header.text == "Directed by"):
            column = table_row.find("td");
            director = clean_string(column.text)
            return director




def get_film_details(detail_url):

    page = requests.get("https://en.wikipedia.org"+detail_url)
    soup = BeautifulSoup(page.content)


    description = from_details_get_film_description(soup)
    director = from_details_get_film_director(soup)
    result = (description, director)
    return result




df["link_detail"].sample(1).map(get_film_details)
# Out:
# 19    (Iron Man 3 is a 2013 American superhero film ...
# Name: link_detail, dtype: object

# %%
from time import perf_counter

time1 = perf_counter()

result = df["link_detail"].map(get_film_details)

time2 = perf_counter()

print("time taken:", time2-time1)
# Out:
# time taken: 13.79202658

# %%
df['description'], df['director'] = zip(*result)

df.head()
# Out:
#   rank                         Title                         link_detail  \
# 0    1             Avengers: Endgame             /wiki/Avengers:_Endgame
# 1    2                        Avatar            /wiki/Avatar_(2009_film)
# 2    3                       Titanic           /wiki/Titanic_(1997_film)
# 3    4  Star Wars: The Force Awakens  /wiki/Star_Wars:_The_Force_Awakens
# 4    5        Avengers: Infinity War        /wiki/Avengers:_Infinity_War
#
#   Worldwide gross ($USD)  Year  \
# 0         $2,797,800,564  2019
# 1         $2,790,439,000  2009
# 2         $2,194,439,542  1997
# 3         $2,068,223,624  2015
# 4         $2,048,359,754  2018
#
#                                          description                director
# 0  Avengers: Endgame is a 2019 American superhero...  Anthony RussoJoe Russo
# 1  Avatar (marketed as James Cameron's Avatar) is...           James Cameron
# 2  Titanic is a 1997 American epic romance and di...           James Cameron
# 3  Star Wars: The Force Awakens (also known as St...            J. J. Abrams
# 4  Avengers: Infinity War is a 2018 American supe...  Anthony RussoJoe Russo

# %%
import multiprocessing as mp
time1 = perf_counter()

with mp.Pool(mp.cpu_count()) as pool:
    threaded_result = pool.map(get_film_details, df["link_detail"])

time2 = perf_counter()

print("time taken:", time2-time1)

df['description'], df['director'] = zip(*threaded_result)
# Out:
# time taken: 2.908397775000001

# %%
df.head(50)
# Out:
#    rank                                          Title  \
# 0     1                              Avengers: Endgame
# 1     2                                         Avatar
# 2     3                                        Titanic
# 3     4                   Star Wars: The Force Awakens
# 4     5                         Avengers: Infinity War
# 5     6                                 Jurassic World
# 6     7                                  The Lion King
# 7     8                                   The Avengers
# 8     9                                      Furious 7
# 9    10                                      Frozen II
# 10   11                        Avengers: Age of Ultron
# 11   12                                  Black Panther
# 12   13  Harry Potter and the Deathly Hallows – Part 2
# 13   14                       Star Wars: The Last Jedi
# 14   15                 Jurassic World: Fallen Kingdom
# 15   16                                         Frozen
# 16   17                           Beauty and the Beast
# 17   18                                  Incredibles 2
# 18   19                        The Fate of the Furious
# 19   20                                     Iron Man 3
# 20   21                                        Minions
# 21   22                     Captain America: Civil War
# 22   23                                        Aquaman
# 23   24  The Lord of the Rings: The Return of the King
# 24   25                      Spider-Man: Far From Home
# 25   26                                 Captain Marvel
# 26   27                 Transformers: Dark of the Moon
# 27   28                                        Skyfall
# 28   29                Transformers: Age of Extinction
# 29   30                          The Dark Knight Rises
# 30   31                                          Joker
# 31   32               Star Wars: The Rise of Skywalker
# 32   33                                    Toy Story 4
# 33   34                                    Toy Story 3
# 34   35     Pirates of the Caribbean: Dead Man's Chest
# 35   36                   Rogue One: A Star Wars Story
# 36   37                                        Aladdin
# 37   38    Pirates of the Caribbean: On Stranger Tides
# 38   39                                Despicable Me 3
# 39   40                                  Jurassic Park
# 40   41                                   Finding Dory
# 41   42      Star Wars: Episode I – The Phantom Menace
# 42   43                            Alice in Wonderland
# 43   44                                       Zootopia
# 44   45              The Hobbit: An Unexpected Journey
# 45   46                                The Dark Knight
# 46   47       Harry Potter and the Philosopher's Stone
# 47   48                                Despicable Me 2
# 48   49                                  The Lion King
# 49   50                                The Jungle Book
#
#                                           link_detail Worldwide gross ($USD)  \
# 0                             /wiki/Avengers:_Endgame         $2,797,800,564
# 1                            /wiki/Avatar_(2009_film)         $2,790,439,000
# 2                           /wiki/Titanic_(1997_film)         $2,194,439,542
# 3                  /wiki/Star_Wars:_The_Force_Awakens         $2,068,223,624
# 4                        /wiki/Avengers:_Infinity_War         $2,048,359,754
# 5                                /wiki/Jurassic_World         $1,671,713,208
# 6                     /wiki/The_Lion_King_(2019_film)         $1,656,943,394
# 7                      /wiki/The_Avengers_(2012_film)         $1,518,812,988
# 8                                     /wiki/Furious_7         $1,516,045,911
# 9                                     /wiki/Frozen_II         $1,450,026,933
# 10                      /wiki/Avengers:_Age_of_Ultron         $1,402,805,868
# 11                         /wiki/Black_Panther_(film)         $1,346,913,161
# 12  /wiki/Harry_Potter_and_the_Deathly_Hallows_%E2...         $1,341,693,157
# 13                     /wiki/Star_Wars:_The_Last_Jedi         $1,332,539,889
# 14               /wiki/Jurassic_World:_Fallen_Kingdom         $1,309,484,461
# 15                           /wiki/Frozen_(2013_film)        F$1,290,000,000
# 16             /wiki/Beauty_and_the_Beast_(2017_film)         $1,263,521,126
# 17                                /wiki/Incredibles_2         $1,242,805,359
# 18                      /wiki/The_Fate_of_the_Furious       F8$1,238,764,765
# 19                                   /wiki/Iron_Man_3         $1,214,811,252
# 20                               /wiki/Minions_(film)         $1,159,398,397
# 21                   /wiki/Captain_America:_Civil_War         $1,153,304,495
# 22                               /wiki/Aquaman_(film)         $1,148,161,807
# 23  /wiki/The_Lord_of_the_Rings:_The_Return_of_the...         $1,142,219,401
# 24                    /wiki/Spider-Man:_Far_From_Home         $1,131,927,996
# 25                        /wiki/Captain_Marvel_(film)         $1,128,274,794
# 26               /wiki/Transformers:_Dark_of_the_Moon         $1,123,794,079
# 27                                      /wiki/Skyfall         $1,108,561,013
# 28              /wiki/Transformers:_Age_of_Extinction         $1,104,054,072
# 29                        /wiki/The_Dark_Knight_Rises         $1,084,939,099
# 30                            /wiki/Joker_(2019_film)         $1,074,251,311
# 31             /wiki/Star_Wars:_The_Rise_of_Skywalker         $1,074,144,248
# 32                                  /wiki/Toy_Story_4         $1,073,394,593
# 33                                  /wiki/Toy_Story_3         $1,066,969,703
# 34  /wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_C...         $1,066,179,725
# 35                 /wiki/Rogue_One:_A_Star_Wars_Story         $1,056,057,273
# 36                          /wiki/Aladdin_(2019_film)         $1,050,693,953
# 37  /wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides         $1,045,713,802
# 38                              /wiki/Despicable_Me_3         $1,034,799,409
# 39                         /wiki/Jurassic_Park_(film)         $1,029,939,903
# 40                                 /wiki/Finding_Dory         $1,028,570,889
# 41  /wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phant...         $1,027,044,677
# 42              /wiki/Alice_in_Wonderland_(2010_film)         $1,025,467,110
# 43                                     /wiki/Zootopia         $1,023,784,195
# 44            /wiki/The_Hobbit:_An_Unexpected_Journey         $1,021,103,568
# 45                       /wiki/The_Dark_Knight_(film)         $1,004,934,033
# 46  /wiki/Harry_Potter_and_the_Philosopher%27s_Sto...           $975,051,288
# 47                              /wiki/Despicable_Me_2           $970,761,885
# 48                                /wiki/The_Lion_King           $968,483,777
# 49                  /wiki/The_Jungle_Book_(2016_film)           $966,550,600
#
#     Year                                        description  \
# 0   2019  Avengers: Endgame is a 2019 American superhero...
# 1   2009  Avatar (marketed as James Cameron's Avatar) is...
# 2   1997  Titanic is a 1997 American epic romance and di...
# 3   2015  Star Wars: The Force Awakens (also known as St...
# 4   2018  Avengers: Infinity War is a 2018 American supe...
# 5   2015  Jurassic World is a 2015 American science fict...
# 6   2019  The Lion King is a 2019 American musical drama...
# 7   2012  Marvel's The Avengers[6] (classified under the...
# 8   2015  Furious 7 (titled onscreen and other territori...
# 9   2019  Frozen II, also known as Frozen 2, is a 2019 A...
# 10  2015  Avengers: Age of Ultron is a 2015 American sup...
# 11  2018  Black Panther is a 2018 American superhero fil...
# 12  2011  Harry Potter and the Deathly Hallows – Part 2 ...
# 13  2017  Star Wars: The Last Jedi (also known as Star W...
# 14  2018  Jurassic World: Fallen Kingdom is a 2018 Ameri...
# 15  2013  Frozen is a 2013 American 3D computer-animated...
# 16  2017  Beauty and the Beast is a 2017 American musica...
# 17  2018  Incredibles 2 is a 2018 American computer-anim...
# 18  2017  The Fate of the Furious (alternatively known a...
# 19  2013  Iron Man 3 is a 2013 American superhero film b...
# 20  2015  Minions is a 2015 American 3D computer-animate...
# 21  2016  Captain America: Civil War is a 2016 American ...
# 22  2018  Aquaman is a 2018 American superhero film base...
# 23  2003  The Lord of the Rings: The Return of the King ...
# 24  2019  Spider-Man: Far From Home is a 2019 American s...
# 25  2019  Captain Marvel is a 2019 American superhero fi...
# 26  2011  Transformers: Dark of the Moon is a 2011 Ameri...
# 27  2012  Skyfall is a 2012 spy film and the twenty-thir...
# 28  2014  Transformers: Age of Extinction is a 2014 Amer...
# 29  2012  The Dark Knight Rises is a 2012 superhero film...
# 30  2019  Joker is a 2019 American psychological thrille...
# 31  2019  Star Wars: The Rise of Skywalker (also known a...
# 32  2019  Toy Story 4 is a 2019 American computer-animat...
# 33  2010  Toy Story 3 is a  2010 American computer-anima...
# 34  2006  Pirates of the Caribbean: Dead Man's Chest is ...
# 35  2016  Rogue One: A Star Wars Story (or simply Rogue ...
# 36  2019  Aladdin is a 2019 American musical fantasy fil...
# 37  2011  Pirates of the Caribbean: On Stranger Tides (r...
# 38  2017  Despicable Me 3 is a 2017 American computer-an...
# 39  1993  Jurassic Park is a 1993 American science ficti...
# 40  2016  Finding Dory is a 2016 American 3D computer-an...
# 41  1999  Star Wars: Episode I – The Phantom Menace is a...
# 42  2010  Alice in Wonderland is a 2010 American dark fa...
# 43  2016  Zootopia (titled Zootropolis in the UK)[6] is ...
# 44  2012  The Hobbit: An Unexpected Journey is a 2012 ep...
# 45  2008  The Dark Knight is a 2008 superhero film direc...
# 46  2001  Harry Potter and the Philosopher's Stone (rele...
# 47  2013  Despicable Me 2 is a 2013 American computer-an...
# 48  1994  The Lion King is a 1994 American animated musi...
# 49  2016  The Jungle Book is  2016 American fantasy adve...
#
#                      director
# 0      Anthony RussoJoe Russo
# 1               James Cameron
# 2               James Cameron
# 3                J. J. Abrams
# 4      Anthony RussoJoe Russo
# 5             Colin Trevorrow
# 6                 Jon Favreau
# 7                 Joss Whedon
# 8                   James Wan
# 9     Chris Buck Jennifer Lee
# 10                Joss Whedon
# 11               Ryan Coogler
# 12                David Yates
# 13               Rian Johnson
# 14               J. A. Bayona
# 15    Chris Buck Jennifer Lee
# 16                Bill Condon
# 17                  Brad Bird
# 18               F. Gary Gray
# 19                Shane Black
# 20   Pierre Coffin Kyle Balda
# 21     Anthony RussoJoe Russo
# 22                  James Wan
# 23              Peter Jackson
# 24                  Jon Watts
# 25       Anna BodenRyan Fleck
# 26                Michael Bay
# 27                 Sam Mendes
# 28                Michael Bay
# 29          Christopher Nolan
# 30              Todd Phillips
# 31               J. J. Abrams
# 32                Josh Cooley
# 33                Lee Unkrich
# 34             Gore Verbinski
# 35             Gareth Edwards
# 36                Guy Ritchie
# 37               Rob Marshall
# 38   Pierre Coffin Kyle Balda
# 39           Steven Spielberg
# 40             Andrew Stanton
# 41               George Lucas
# 42                 Tim Burton
# 43    Byron Howard Rich Moore
# 44              Peter Jackson
# 45          Christopher Nolan
# 46             Chris Columbus
# 47  Chris RenaudPierre Coffin
# 48    Roger AllersRob Minkoff
# 49                Jon Favreau

# %%
df.to_csv("Top grossing films.csv", columns=["rank", "Title", "Worldwide gross ($USD)" , "Year","description", "director"])
